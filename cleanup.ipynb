# %%
import os
import pandas as pd
import numpy as np

# %%
path='Data'
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

bike_df = pd.DataFrame()

for file in files:
    bike_data = pd.read_csv(path+"/"+file)
    bike_df = pd.concat([bike_data, bike_df])

print(bike_df.shape)
print(bike_df.columns)
# Out:
# (12851412, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2013  2020-08-01 00:00:00.8790  2020-08-01 00:33:34.7260
# 1          7002  2020-08-01 00:00:01.5910  2020-08-01 01:56:44.0720
# 2           155  2020-08-01 00:00:03.5810  2020-08-01 00:02:38.6340
# 3          2720  2020-08-01 00:00:05.0130  2020-08-01 00:45:25.3270
# 4          2938  2020-08-01 00:00:05.9420  2020-08-01 00:49:03.9640
#
#    start station id                   start station name  \
# 0            3295.0             Central Park W & W 96 St
# 1            3144.0                   E 81 St & Park Ave
# 2             387.0              Centre St & Chambers St
# 3            3080.0                   S 4 St & Rodney St
# 4            3510.0  Adam Clayton Powell Blvd & W 123 St
#
#    start station latitude  start station longitude  end station id  \
# 0               40.791270               -73.964839          3992.0
# 1               40.776777               -73.959010          3671.0
# ...

# %%
bike_df = bike_df.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Lat",
                                            "start station longitude": "Start Station Lon",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Lat",
                                            "end station longitude": "End Station Lon",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
bike_df.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0           2013  2020-08-01 00:00:00.8790  2020-08-01 00:33:34.7260
# 1           7002  2020-08-01 00:00:01.5910  2020-08-01 01:56:44.0720
# 2            155  2020-08-01 00:00:03.5810  2020-08-01 00:02:38.6340
# 3           2720  2020-08-01 00:00:05.0130  2020-08-01 00:45:25.3270
# 4           2938  2020-08-01 00:00:05.9420  2020-08-01 00:49:03.9640
#
#    Start Station ID                   Start Station Name  Start Station Lat  \
# 0            3295.0             Central Park W & W 96 St          40.791270
# 1            3144.0                   E 81 St & Park Ave          40.776777
# 2             387.0              Centre St & Chambers St          40.712733
# 3            3080.0                   S 4 St & Rodney St          40.709340
# 4            3510.0  Adam Clayton Powell Blvd & W 123 St          40.807832
#
#    Start Station Lon  End Station ID                End Station Name  \
# ...

# %%
bike_df.dtypes
# Out:
# Trip Duration           int64
# Start Time             object
# Stop Time              object
# Start Station ID      float64
# Start Station Name     object
# Start Station Lat     float64
# Start Station Lon     float64
# End Station ID        float64
# End Station Name       object
# End Station Lat       float64
# End Station Lon       float64
# Bike ID                 int64
# User Type              object
# Birth Year              int64
# Gender                  int64
# dtype: object

# %%
bike_df['Birth Year'].min()
# Out:
# 1873

# %%
bike_df['Birth Year'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          1998
# 1          1966
# 2          1969
# 3          1990
# 4          1969
#            ...
# 1913620    1969
# 1913621    1995
# 1913622    1985
# 1913623    1989
# 1913624    1974
# Name: Birth Year, Length: 12851412, dtype: int64>

# %%
bike_df['Birth Year'].max()
# Out:
# 2004

# %%
age_filt = bike_df['Birth Year'] <= 1920

# %%
bike_df = bike_df[~age_filt]

# %%
bike_df.shape
# Out:
# (12844947, 15)

# %%
filt_1940 = bike_df['Birth Year'] <= 1950

# %%
bike_df[filt_1940]
# Out:
#          Trip Duration                Start Time                 Stop Time  \
# 247                 89  2020-08-01 00:07:09.5500  2020-08-01 00:08:38.9170
# 630                511  2020-08-01 00:19:26.7140  2020-08-01 00:27:58.1630
# 677                608  2020-08-01 00:20:53.5150  2020-08-01 00:31:01.5770
# 696                305  2020-08-01 00:21:25.9030  2020-08-01 00:26:31.7900
# 962                102  2020-08-01 00:31:07.0570  2020-08-01 00:32:49.2690
# ...                ...                       ...                       ...
# 1913102            867  2018-07-30 20:23:10.1020  2018-07-30 20:37:37.1320
# 1913170            540  2018-07-31 11:31:41.5210  2018-07-31 11:40:41.5670
# 1913478            764  2018-07-30 18:28:42.7390  2018-07-30 18:41:27.4640
# 1913504           1863  2018-07-30 22:38:16.5720  2018-07-30 23:09:20.4040
# 1913577            340  2018-07-31 16:33:13.6480  2018-07-31 16:38:53.7880
#
#          Start Station ID                Start Station Name  \
# ...

# %%
bike_df['Age'] = bike_df['Birth Year'].apply(lambda x: 2020 - x)
bike_df.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0           2013  2020-08-01 00:00:00.8790  2020-08-01 00:33:34.7260
# 1           7002  2020-08-01 00:00:01.5910  2020-08-01 01:56:44.0720
# 2            155  2020-08-01 00:00:03.5810  2020-08-01 00:02:38.6340
# 3           2720  2020-08-01 00:00:05.0130  2020-08-01 00:45:25.3270
# 4           2938  2020-08-01 00:00:05.9420  2020-08-01 00:49:03.9640
#
#    Start Station ID                   Start Station Name  Start Station Lat  \
# 0            3295.0             Central Park W & W 96 St          40.791270
# 1            3144.0                   E 81 St & Park Ave          40.776777
# 2             387.0              Centre St & Chambers St          40.712733
# 3            3080.0                   S 4 St & Rodney St          40.709340
# 4            3510.0  Adam Clayton Powell Blvd & W 123 St          40.807832
#
#    Start Station Lon  End Station ID                End Station Name  \
# ...

# %%
bike_df.to_csv("Out/citi_bike.csv", index=False, header=True)
